# %% [markdown]
# # 09__cis_trans_interactions

# %%
import warnings
warnings.filterwarnings('ignore')

import itertools
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import sys

from itertools import combinations 
from scipy.stats import linregress
from scipy.stats import spearmanr
from scipy.stats import pearsonr

from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors

# import utils
sys.path.append("../../../utils")
from plotting_utils import *
from misc_utils import *
from norm_utils import *

# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
mpl.rcParams['figure.autolayout'] = False

# %%
sns.set(**PAPER_PRESET)
fontsize = PAPER_FONTSIZE

# %%
np.random.seed(2019)

# %% [markdown]
# ## functions

# %%
def is_ctrl(row):
    if "CONTROL" in row["index"]:
        return "control"
    else:
        return "TSS"

# %%
def cis_trans_int_status(row):
    if row.fdr < 0.1:
        return "significant cis/trans interaction"
    else:
        return "no cis/trans interaction"

# %%
def cis_trans_int_status_detail(row):
    if row.fdr < 0.1:
        if row.logFC < 0:
            return "cis effect\n(higher in human)"
        else:
            return "cis effect\n(higher in mouse)"
    else:
        return "no cis effect"

# %% [markdown]
# ## variables

# %%
results_dir = "../../../data/02__mpra/03__results"
results_f = "%s/native_cis_trans_effects_data.txt" % results_dir

# %%
data_dir = "../../../data/02__mpra/02__activs"
cis_trans_int_f = "%s/cis_trans_interaction_results.txt" % data_dir

# %% [markdown]
# ## 1. import data

# %%
results = pd.read_table(results_f)
results.head()
# Out:
#   chr_tss_hg19  start_tss_hg19  end_tss_hg19 strand_tss_hg19  \
# 0         chr1         2985430       2985431               -
# 1         chr1         8086552       8086553               +
# 2         chr1        26498322      26498323               -
# 3         chr1        65533428      65533429               -
# 4         chr1        65533462      65533463               -
#
#                 cage_id_hg19    biotype_hg19     name_peak_hg19  seq_orth  \
# 0    chr1:2985420..2985438,-         div_lnc  ENSG00000177133.6      True
# 1    chr1:8086546..8086571,+         div_lnc  ENSG00000238290.1      True
# 2  chr1:26498321..26498327,-  antisense_upep  ENSG00000236782.1      True
# 3  chr1:65533390..65533443,-      intergenic  ENSG00000231485.1      True
# 4  chr1:65533457..65533465,-      intergenic  ENSG00000231485.1      True
#
#    cage_orth chr_tss_mm9         ...                trans_status_detail_human  \
# 0       True        chr4         ...                          no trans effect
# 1       True        chr4         ...                          no trans effect
# 2       True        chr4         ...                          no trans effect
# 3       True        chr4         ...          trans effect\n(higher in mouse)
# 4       True        chr4         ...                          no trans effect
#
#    fdr_trans_mouse logFC_trans_mouse abs_logFC_trans_mouse  \
# 0         0.048368         -0.463429              0.463429
# 1         0.071236          0.472766              0.472766
# 2         0.989347          0.005199              0.005199
# 3         0.000066          0.442638              0.442638
# 4         0.000066          0.442638              0.442638
#
#          trans_status_mouse        trans_status_detail_mouse  \
# 0           no trans effect                  no trans effect
# 1           no trans effect                  no trans effect
# 2           no trans effect                  no trans effect
# 3  significant trans effect  trans effect\n(higher in mouse)
# 4  significant trans effect  trans effect\n(higher in mouse)
#
#            trans_status_one          trans_status_detail_one logFC_trans_max  \
# 0           no trans effect                  no trans effect       -0.463429
# 1           no trans effect                  no trans effect        0.867449
# 2           no trans effect                  no trans effect        0.404031
# 3  significant trans effect  trans effect\n(higher in mouse)        0.442638
# 4  significant trans effect  trans effect\n(higher in mouse)        0.442638
#
#   abs_logFC_trans_max
# 0            0.463429
# 1            0.867449
# 2            0.404031
# 3            0.442638
# 4            0.442638
#
# [5 rows x 77 columns]

# %%
cis_trans_int = pd.read_table(cis_trans_int_f).reset_index()
cis_trans_int.head()
# Out:
#                                       index  statistic      pval       fdr  \
# 0                h.2__div_lnc__m.1__div_lnc   0.142962  0.705354  1.000000
# 1              h.3__div_lnc__m.2__antisense   2.049584  0.152248  0.838632
# 2  h.4__antisense_upep__m.3__protein_coding   2.357235  0.124703  0.788286
# 3     h.5__intergenic__m.4__intergenic_upep   0.344569  0.557204  0.999651
# 4     h.6__intergenic__m.4__intergenic_upep   0.476280  0.490112  0.982861
#
#    df.test  df.dna  df.rna.full  df.rna.red     logFC
# 0        1      14            9           8 -0.182794
# 1        1      13            9           8 -1.069364
# 2        1      14            9           8 -0.596741
# 3        1      14            9           8  0.204224
# 4        1      14            9           8  0.232788

# %% [markdown]
# ## 2. plot controls

# %%
cis_trans_int["ctrl_status"] = cis_trans_int.apply(is_ctrl, axis=1)
cis_trans_int.ctrl_status.value_counts()
# Out:
# TSS        3279
# control     400
# Name: ctrl_status, dtype: int64

# %%
fig = plt.figure(figsize=(1.5, 1))
sns.distplot(cis_trans_int[cis_trans_int["ctrl_status"] == "control"]["pval"], hist=False, color="gray",
             label="negative controls (n=%s)" % len(cis_trans_int[cis_trans_int["ctrl_status"] == "control"]))
sns.distplot(cis_trans_int[cis_trans_int["ctrl_status"] != "control"]["pval"], hist=False, color="black",
             label="TSSs (n=%s)" % len(cis_trans_int[cis_trans_int["ctrl_status"] != "control"]))

plt.ylabel("density")
plt.xlabel("cis/trans interaction p-value")
plt.legend(loc=2, bbox_to_anchor=(1.05, 1.05))
fig.savefig("cis_trans_int_ctrl_pval_dist.pdf", dpi="figure", bbox_inches="tight")

# %%
cis_trans_int["abs_logFC"] = np.abs(cis_trans_int["logFC"])

# %%
order = ["control", "TSS"]
pal = {"control": "gray", "TSS": "black"}

# %%
fig = plt.figure(figsize=(1, 1.5))
ax = sns.boxplot(data=cis_trans_int, x="ctrl_status", y="abs_logFC", flierprops = dict(marker='o', markersize=5), 
                 order=order, palette=pal)
mimic_r_boxplot(ax)

ax.set_xticklabels(["negative\ncontrols", "TSSs"], rotation=50, ha='right', va='top')
ax.set_xlabel("")
ax.set_ylabel("cis/trans interaction effect size")

for i, label in enumerate(order):
    n = len(cis_trans_int[cis_trans_int["ctrl_status"] == label])
    color = pal[label]
    ax.annotate(str(n), xy=(i, -0.5), xycoords="data", xytext=(0, 0), 
                textcoords="offset pixels", ha='center', va='bottom', 
                color=color, size=fontsize)

ax.set_ylim((-0.6, 4))

# calc p-vals b/w dists
dist1 = np.asarray(cis_trans_int[cis_trans_int["ctrl_status"] == "control"]["abs_logFC"])
dist2 = np.asarray(cis_trans_int[cis_trans_int["ctrl_status"] != "control"]["abs_logFC"])

dist1 = dist1[~np.isnan(dist1)]
dist2 = dist2[~np.isnan(dist2)]

u, pval = stats.mannwhitneyu(dist1, dist2, alternative="two-sided", use_continuity=False)
print(pval)

annotate_pval(ax, 0.2, 0.8, 0.77, 0, 0.7, pval, fontsize)
fig.savefig("cis_trans_int_ctrl_effectsize_boxplot.pdf", dpi="figure", bbox_inches="tight")
# Out:
# 2.94390435212e-54

# %% [markdown]
# ## 3. classify cis/trans interaction effects

# %%
cis_trans_int["cis_trans_int_status"] = cis_trans_int.apply(cis_trans_int_status, axis=1)
cis_trans_int.cis_trans_int_status.value_counts()
# Out:
# no cis/trans interaction             3647
# significant cis/trans interaction      32
# Name: cis_trans_int_status, dtype: int64

# %%
cis_trans_int[cis_trans_int["cis_trans_int_status"].str.contains("significant")]
# Out:
#                                                   index  statistic  \
# 54                         h.58__div_lnc__m.37__div_lnc  11.231223
# 1020                 h.1148__enhancer__m.1020__enhancer  11.128874
# 1275                 h.1280__enhancer__m.1152__enhancer  11.634861
# 1305                 h.1485__enhancer__m.1310__enhancer  11.410400
# 1323                 h.1305__enhancer__m.1177__enhancer  28.691679
# 1324                 h.1495__enhancer__m.1177__enhancer  17.060773
# 1390        h.1534__antisense__m.1346__no cage activity  22.097870
# 1399   h.1543__antisense_upep__m.1355__no cage activity  26.188545
# 1411   h.1555__antisense_upep__m.1367__no cage activity  25.711680
# 1474        h.1627__antisense__m.1439__no cage activity  16.884810
# 1494   h.1653__antisense_upep__m.1465__no cage activity  11.528986
# 1516        h.1677__antisense__m.1489__no cage activity  13.276530
# 1567          h.1738__div_lnc__m.1550__no cage activity  12.838146
# 1643          h.1827__div_lnc__m.1639__no cage activity  14.803243
# 1747       h.1949__intergenic__m.1761__no cage activity  13.024455
# 1765  h.1968__intergenic_upep__m.1780__no cage activity  12.869326
# 1783       h.1988__intergenic__m.1800__no cage activity  14.117953
# 1890          h.2113__div_lnc__m.1925__no cage activity  12.140503
# 1917  h.2142__intergenic_upep__m.1954__no cage activity  12.250236
# 1922       h.2147__intergenic__m.1959__no cage activity  15.188656
# 2085   h.2343__protein_coding__m.2155__no cage activity  11.464278
# 2180         h.2413__enhancer__m.2225__no cage activity  23.697545
# 2252         h.2550__enhancer__m.2362__no cage activity  17.593886
# 2263         h.2556__enhancer__m.2368__no cage activity  13.536438
# 2274         h.2462__enhancer__m.2274__no cage activity  11.269316
# 2488        h.2720__no cage activity__m.2532__antisense  13.343773
# 2556          h.2806__no cage activity__m.2617__div_lnc  12.210397
# 2814  h.3110__no cage activity__m.2921__intergenic_upep  12.308176
# 2820  h.3116__no cage activity__m.2927__intergenic_upep  18.500788
# 2959           h.3261__no cage activity__m.3071__div_pc  11.747652
# 3070   h.3387__no cage activity__m.3197__protein_coding  15.917418
# 3112         h.3421__no cage activity__m.3231__enhancer  17.976985
#
#               pval       fdr  df.test  df.dna  df.rna.full  df.rna.red  \
# 54    8.043264e-04  0.095455        1      14            9           8
# 1020  8.499416e-04  0.097717        1      14            9           8
# 1275  6.472717e-04  0.091589        1      14            9           8
# 1305  7.303411e-04  0.092653        1      14            9           8
# 1323  8.486762e-08  0.000312        1      14            9           8
# 1324  3.620242e-05  0.014612        1      14            9           8
# 1390  2.590971e-06  0.001906        1      14            9           8
# 1399  3.096540e-07  0.000486        1      14            9           8
# 1411  3.964206e-07  0.000486        1      14            9           8
# 1474  3.971816e-05  0.014612        1      14            9           8
# 1494  6.851939e-04  0.092653        1      14            9           8
# 1516  2.687495e-04  0.058161        1      13            9           8
# 1567  3.396240e-04  0.062474        1      14            9           8
# 1643  1.193301e-04  0.033770        1      14            9           8
# 1747  3.074496e-04  0.062474        1      14            9           8
# 1765  3.340118e-04  0.062474        1      13            9           8
# 1783  1.716973e-04  0.045120        1      14            9           8
# 1890  4.933846e-04  0.075632        1      14            9           8
# 1917  4.651994e-04  0.075632        1      14            9           8
# 1922  9.728609e-05  0.029826        1      14            9           8
# 2085  7.094680e-04  0.092653        1      14            9           8
# 2180  1.127263e-06  0.001037        1      14            9           8
# 2252  2.734661e-05  0.012576        1      14            9           8
# 2263  2.339761e-04  0.057387        1      14            9           8
# 2274  7.879876e-04  0.095455        1      14            9           8
# 2488  2.592822e-04  0.058161        1      13            9           8
# 2556  4.752391e-04  0.075632        1      13            9           8
# 2814  4.509784e-04  0.075632        1      14            9           8
# 2820  1.698341e-05  0.010414        1      14            9           8
# 2959  6.092004e-04  0.089650        1      14            9           8
# 3070  6.616698e-05  0.022130        1      14            9           8
# 3112  2.235920e-05  0.011751        1      14            9           8
#
#          logFC ctrl_status  abs_logFC               cis_trans_int_status
# 54    1.558773         TSS   1.558773  significant cis/trans interaction
# 1020  1.528354         TSS   1.528354  significant cis/trans interaction
# 1275  1.626417         TSS   1.626417  significant cis/trans interaction
# 1305 -1.466196         TSS   1.466196  significant cis/trans interaction
# 1323  1.660750         TSS   1.660750  significant cis/trans interaction
# 1324  1.485179         TSS   1.485179  significant cis/trans interaction
# 1390  1.651913         TSS   1.651913  significant cis/trans interaction
# 1399  2.490760         TSS   2.490760  significant cis/trans interaction
# 1411  2.040470         TSS   2.040470  significant cis/trans interaction
# 1474  2.764600         TSS   2.764600  significant cis/trans interaction
# 1494  1.495772         TSS   1.495772  significant cis/trans interaction
# 1516  3.366737         TSS   3.366737  significant cis/trans interaction
# 1567  1.516842         TSS   1.516842  significant cis/trans interaction
# 1643  1.711166         TSS   1.711166  significant cis/trans interaction
# 1747  1.538712         TSS   1.538712  significant cis/trans interaction
# 1765  2.333524         TSS   2.333524  significant cis/trans interaction
# 1783  1.140512         TSS   1.140512  significant cis/trans interaction
# 1890 -1.292833         TSS   1.292833  significant cis/trans interaction
# 1917  1.783269         TSS   1.783269  significant cis/trans interaction
# 1922  1.503114         TSS   1.503114  significant cis/trans interaction
# 2085  1.456126         TSS   1.456126  significant cis/trans interaction
# 2180  1.811460         TSS   1.811460  significant cis/trans interaction
# 2252  1.330702         TSS   1.330702  significant cis/trans interaction
# 2263  1.908595         TSS   1.908595  significant cis/trans interaction
# 2274 -1.400940         TSS   1.400940  significant cis/trans interaction
# 2488  2.206652         TSS   2.206652  significant cis/trans interaction
# 2556  3.156881         TSS   3.156881  significant cis/trans interaction
# 2814  1.760614         TSS   1.760614  significant cis/trans interaction
# 2820  1.840192         TSS   1.840192  significant cis/trans interaction
# 2959  1.407665         TSS   1.407665  significant cis/trans interaction
# 3070  2.037156         TSS   2.037156  significant cis/trans interaction
# 3112  1.950325         TSS   1.950325  significant cis/trans interaction

# %%
results[(results["hg19_id"] == "h.1305") & (results["mm9_id"] == "m.1177")][["logFC_cis_HUES64", "logFC_cis_mESC"]]
# Out:
#       logFC_cis_HUES64  logFC_cis_mESC
# 1329         -1.240528        0.407642

# %%
results[(results["hg19_id"] == "h.2113") & (results["mm9_id"] == "m.1925")][["logFC_cis_HUES64", "logFC_cis_mESC"]]
# Out:
#       logFC_cis_HUES64  logFC_cis_mESC
# 1896          0.714335       -0.655043

# %% [markdown]
# almost all significant examples are ones where the mouse seq. does not work in human but then does [better] in mouse -- these have a logFC > 0. why are there so few examples of the opposite?

# %% [markdown]
# ## 4. merge w/ existing data

# %%
cis_trans_int["hg19_id"] = cis_trans_int["index"].str.split("__", expand=True)[0]
cis_trans_int["biotype_hg19"] = cis_trans_int["index"].str.split("__", expand=True)[1]
cis_trans_int["mm9_id"] = cis_trans_int["index"].str.split("__", expand=True)[2]
cis_trans_int["biotype_mm9"] = cis_trans_int["index"].str.split("__", expand=True)[3]
cis_trans_int.head()
# Out:
#                                       index  statistic      pval       fdr  \
# 0                h.2__div_lnc__m.1__div_lnc   0.142962  0.705354  1.000000
# 1              h.3__div_lnc__m.2__antisense   2.049584  0.152248  0.838632
# 2  h.4__antisense_upep__m.3__protein_coding   2.357235  0.124703  0.788286
# 3     h.5__intergenic__m.4__intergenic_upep   0.344569  0.557204  0.999651
# 4     h.6__intergenic__m.4__intergenic_upep   0.476280  0.490112  0.982861
#
#    df.test  df.dna  df.rna.full  df.rna.red     logFC ctrl_status  abs_logFC  \
# 0        1      14            9           8 -0.182794         TSS   0.182794
# 1        1      13            9           8 -1.069364         TSS   1.069364
# 2        1      14            9           8 -0.596741         TSS   0.596741
# 3        1      14            9           8  0.204224         TSS   0.204224
# 4        1      14            9           8  0.232788         TSS   0.232788
#
#        cis_trans_int_status hg19_id    biotype_hg19 mm9_id      biotype_mm9
# 0  no cis/trans interaction     h.2         div_lnc    m.1          div_lnc
# 1  no cis/trans interaction     h.3         div_lnc    m.2        antisense
# 2  no cis/trans interaction     h.4  antisense_upep    m.3   protein_coding
# 3  no cis/trans interaction     h.5      intergenic    m.4  intergenic_upep
# 4  no cis/trans interaction     h.6      intergenic    m.4  intergenic_upep

# %%
cis_trans_int = cis_trans_int[["hg19_id", "biotype_hg19", "mm9_id", "biotype_mm9", "fdr", "logFC", "abs_logFC",
                               "cis_status", "cis_status_detail"]]
HUES64_cis_sub.columns = ["hg19_id", "biotype_hg19", "mm9_id", "biotype_mm9", "fdr_cis_HUES64", "logFC_cis_HUES64", 
                          "abs_logFC_cis_HUES64", "cis_status_HUES64", "cis_status_detail_HUES64"]
